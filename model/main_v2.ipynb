# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib
from Constants import *

# %%
dataset = keras.preprocessing.image_dataset_from_directory(
    DATA_PATH,
    shuffle = True,
    image_size = (image_size, image_size),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
print(class_names)
num_classes = len(class_names)
print(num_classes)
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']
# 3

# %%
plt.figure(figsize = (10, 8))
for image_batch, label_batch in dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
train_size = int(0.75 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = int(0.15 * len(dataset)) + 1

# %%
train_set = dataset.take(train_size)
test_set = dataset.skip(train_size)

# %%
val_set = test_set.take(val_size)
test_set = test_set.skip(val_size)

# %%
print(len(train_set))
print(len(test_set))
print(len(val_set))
# Out:
# 51
# 11
# 6

# %%
train_set = train_set.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
test_set = test_set.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
val_set = val_set.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
resize_and_rescale = keras.Sequential([
    layers.experimental.preprocessing.Resizing(image_size, image_size),
    layers.experimental.preprocessing.Rescaling(1.0 / 255)
])

# %%
augmented_data = keras.Sequential([
    layers.RandomFlip("horizontal",
                      input_shape = (image_size, image_size,
                                     3)),
    layers.RandomRotation(0.25),
    layers.RandomZoom(0.25),
    layers.RandomFlip("horizontal_and_vertical")
])

# %%
plt.figure(figsize = (8, 6))
for images, label in train_set.take(1):
    for i in range(9):
        augmented_images = augmented_data(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.title(class_names[label[0]])
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
input_shape = (BATCH_SIZE, image_size, image_size, num_classes)

model = keras.Sequential([
    resize_and_rescale,
    augmented_data,
    layers.Conv2D(64, (3, 3), activation = 'relu', input_shape = input_shape),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Conv2D(32, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Conv2D(32, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dropout(0.25),
    layers.Dense(num_classes, activation = 'softmax'),    
])

model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (32, 254, 254, 64)        1792
#
#  max_pooling2d (MaxPooling2  (32, 127, 127, 64)        0
#  D)
#
#  dropout (Dropout)           (32, 127, 127, 64)        0
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (32, 62, 62, 32)          0
#  g2D)
#
#  dropout_1 (Dropout)         (32, 62, 62, 32)          0
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          18496
#
#  max_pooling2d_2 (MaxPoolin  (32, 30, 30, 64)          0
#  g2D)
#
#  dropout_2 (Dropout)         (32, 30, 30, 64)          0
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 32)          18464
#
#  max_pooling2d_3 (MaxPoolin  (32, 14, 14, 32)          0
#  g2D)
#
#  dropout_3 (Dropout)         (32, 14, 14, 32)          0
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          18496
#
#  max_pooling2d_4 (MaxPoolin  (32, 6, 6, 64)            0
#  g2D)
#
#  dropout_4 (Dropout)         (32, 6, 6, 64)            0
#
#  flatten (Flatten)           (32, 2304)                0
#
#  dense (Dense)               (32, 64)                  147520
#
#  dropout_5 (Dropout)         (32, 64)                  0
#
#  dense_1 (Dense)             (32, 3)                   195
#
# =================================================================
# Total params: 223427 (872.76 KB)
# Trainable params: 223427 (872.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_set,
                    validation_data = val_set,
                    batch_size = BATCH_SIZE,
                    epochs = 25,
                    verbose = 1
                    )
# Out:
# Epoch 1/25
# 51/51 [==============================] - 195s 4s/step - loss: 0.9208 - accuracy: 0.4749 - val_loss: 0.8779 - val_accuracy: 0.6771
# Epoch 2/25
# 51/51 [==============================] - 190s 4s/step - loss: 0.8039 - accuracy: 0.6440 - val_loss: 0.6425 - val_accuracy: 0.8333
# Epoch 3/25
# 51/51 [==============================] - 188s 4s/step - loss: 0.6069 - accuracy: 0.7543 - val_loss: 0.4654 - val_accuracy: 0.8646
# Epoch 4/25
# 51/51 [==============================] - 190s 4s/step - loss: 0.4515 - accuracy: 0.8143 - val_loss: 0.3097 - val_accuracy: 0.9115
# Epoch 5/25
# 51/51 [==============================] - 188s 4s/step - loss: 0.3560 - accuracy: 0.8566 - val_loss: 0.3171 - val_accuracy: 0.9010
# Epoch 6/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.3653 - accuracy: 0.8536 - val_loss: 0.3526 - val_accuracy: 0.8438
# Epoch 7/25
# 51/51 [==============================] - 186s 4s/step - loss: 0.3201 - accuracy: 0.8909 - val_loss: 0.2375 - val_accuracy: 0.9115
# Epoch 8/25
# 51/51 [==============================] - 186s 4s/step - loss: 0.2405 - accuracy: 0.9130 - val_loss: 0.2585 - val_accuracy: 0.8958
# Epoch 9/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.2868 - accuracy: 0.8952 - val_loss: 0.2020 - val_accuracy: 0.9219
# Epoch 10/25
# 51/51 [==============================] - 186s 4s/step - loss: 0.2368 - accuracy: 0.9118 - val_loss: 0.3752 - val_accuracy: 0.8229
# Epoch 11/25
# 51/51 [==============================] - 188s 4s/step - loss: 0.2673 - accuracy: 0.8928 - val_loss: 0.2920 - val_accuracy: 0.8750
# Epoch 12/25
# 51/51 [==============================] - 188s 4s/step - loss: 0.2188 - accuracy: 0.9210 - val_loss: 0.2230 - val_accuracy: 0.9062
# Epoch 13/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.2047 - accuracy: 0.9216 - val_loss: 0.1479 - val_accuracy: 0.9271
# Epoch 14/25
# 51/51 [==============================] - 189s 4s/step - loss: 0.1951 - accuracy: 0.9240 - val_loss: 0.1581 - val_accuracy: 0.9479
# Epoch 15/25
# 51/51 [==============================] - 185s 4s/step - loss: 0.1741 - accuracy: 0.9381 - val_loss: 0.2526 - val_accuracy: 0.9010
# Epoch 16/25
# 51/51 [==============================] - 189s 4s/step - loss: 0.1580 - accuracy: 0.9406 - val_loss: 0.1782 - val_accuracy: 0.9427
# Epoch 17/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.1723 - accuracy: 0.9449 - val_loss: 0.2311 - val_accuracy: 0.9271
# Epoch 18/25
# 51/51 [==============================] - 192s 4s/step - loss: 0.1856 - accuracy: 0.9259 - val_loss: 0.1628 - val_accuracy: 0.9271
# Epoch 19/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.1722 - accuracy: 0.9455 - val_loss: 0.1278 - val_accuracy: 0.9323
# Epoch 20/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.1708 - accuracy: 0.9412 - val_loss: 0.2441 - val_accuracy: 0.8854
# Epoch 21/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.1494 - accuracy: 0.9461 - val_loss: 0.4560 - val_accuracy: 0.8542
# Epoch 22/25
# 51/51 [==============================] - 186s 4s/step - loss: 0.1294 - accuracy: 0.9534 - val_loss: 0.3188 - val_accuracy: 0.8906
# Epoch 23/25
# 51/51 [==============================] - 187s 4s/step - loss: 0.1327 - accuracy: 0.9540 - val_loss: 0.1170 - val_accuracy: 0.9583
# Epoch 24/25
# 51/51 [==============================] - 185s 4s/step - loss: 0.1457 - accuracy: 0.9442 - val_loss: 0.2262 - val_accuracy: 0.9115
# Epoch 25/25
# 51/51 [==============================] - 184s 4s/step - loss: 0.1019 - accuracy: 0.9632 - val_loss: 0.2876 - val_accuracy: 0.9010

# %%
loss = model.evaluate(test_set)
loss
# Out:
# 11/11 [==============================] - 9s 581ms/step - loss: 0.3533 - accuracy: 0.8872
# [0.35329627990722656, 0.8871951103210449]

# %%
history = history.history

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

# %%
plt.plot(acc, label = "Training Accuracy")
plt.plot(val_acc, label = "Validation Accuracy")
plt.legend(loc = 'lower right')
plt.title("Training and Validation accuracy")
plt.show()

# %%
plt.plot(loss, label = "Training loss")
plt.plot(val_loss, label = "Validation loss")
plt.legend(loc = 'upper right')
plt.title("Training and Validation Loss")
plt.show()

# %%
model_version = 1
model.save(f"../saved_models/{model_version}")

# make changes to model architecture and save it by changing the model version number
# Out:
# INFO:tensorflow:Assets written to: ../saved_models/1\assets
# INFO:tensorflow:Assets written to: ../saved_models/1\assets

# %%
model = tf.keras.models.load_model("../saved_models/1")

# %%
for images_batch, labels_batch in test_set.take(1):
    displayed_image = images_batch[0].numpy().astype("uint8")
    image_label = labels_batch[0].numpy()
    
    print("Predicting on sample from test set...")
    plt.imshow(displayed_image)
    plt.axis("off")
    image_prediction = model.predict(images_batch)
    actual = class_names[np.argmax(image_prediction[0])]
    predicted = class_names[image_label]
    print("Predicted label: ", actual)
    print("Actual label:", predicted)
# Out:
# Predicting on sample from test set...
# 1/1 [==============================] - 2s 2s/step
# Predicted label:  Potato___Early_blight
# Actual label: Potato___Early_blight

# %%
if actual == predicted:
    print("Prediction matches!")
else:
    print("Wrong prediction!")
# Out:
# Prediction matches!

# %%
def predict(model, img):
    image_array = keras.preprocessing.image.img_to_array(images[1].numpy())
    image_array = tf.expand_dims(image_array, 0)
    
    predictions = model.predict(image_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
def predict(model, img):
    image_array = keras.preprocessing.image.img_to_array(images[1].numpy())
    image_array = tf.expand_dims(image_array, 0)
    
    predictions = model.predict(image_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence  

plt.figure(figsize = (12, 10))
for images, labels in test_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        
        #plt.title("Actual class: {}, \n Predicted class: {}, \n Confidence: {}%", actual_class, predicted_class, confidence)
        plt.title(f"Actual: {actual_class}, \n Predicted: {predicted_class}, \n Confidence: {confidence}%")
        plt.axis("off")

# %%
plt.figure(figsize = (12, 10))
for images, labels in test_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        
        #plt.title("Actual class: {}, \n Predicted class: {}, \n Confidence: {}%", actual_class, predicted_class, confidence)
        plt.title(f"Actual: {actual_class}, \n Predicted: {predicted_class}, \n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 109ms/step
